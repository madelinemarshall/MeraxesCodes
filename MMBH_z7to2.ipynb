# %% [markdown]
# ## Evolution of the most massive black holes at redshifts between 7 and 2
# Plots the BH mass, bulge mass and BH/bulge mass ratio as a function of time for the galaxies which host the most massive black holes at z=7, 6 (same as 5), 4, 3 and 2

# %%
#Sets plot defaults
import matplotlib
matplotlib.rcParams['font.size'] = (20)
matplotlib.rcParams['figure.figsize'] = (8,5)

import warnings
warnings.filterwarnings('ignore')

# %%
run 'MMBH_z7to2_histories.py'
