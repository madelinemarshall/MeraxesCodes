# %%
#Sets plot defaults
import matplotlib
matplotlib.rcParams['font.size'] = (30)
matplotlib.rcParams['figure.figsize'] = (12,8)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

import warnings
warnings.filterwarnings('ignore')

# %%
run plotBHMF.py

# %%
run MvirStellarMassRelation.py
# Out:
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:929: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
run plotQLF.py
# Out:
# Yuxiang/_meraxes_util.py:146: RuntimeWarning: divide by zero encountered in log10
#   return 4.74 - 2.5*np.log10(Lbol)
# Yuxiang/_meraxes_util.py:150: RuntimeWarning: divide by zero encountered in power
#   return 6.25 * (Lbol/1e10)**-0.37 + 9.00 * (Lbol/1e10)**-0.012
# ['Jiang et al. 2016', 'Dijkstra & Wyithe 2006; z:~5.7', 'Dijkstra & Wyithe 2006; z:~6.6', 'Willott et al. 2010; z:~6', 'Giallongo et al. 2015']
# ['Wolf et al. 2003; z:3.6-4.2', 'Dijkstra & Wyithe 2006; z:~4.5', 'Gilkman et al. 2011; z:~4', 'Gilkman et al. 2011; z:~4', 'Masters et al. 2012; z:~4', 'Giallongo et al. 2015']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/home/mmarshal/PhD/simulation_codes/plotQLF.py in <module>()
#      91   lab2=(axes[1].get_legend_handles_labels()[1])
#      92   print(lab2)
# ---> 93   plt.legend(hand.append(hand2),lab.append(lab2))
#      94   #plt.tight_layout()
# ...

# %%
run plotSMF_decomposed.py
# Out:
# /mnt/home/mmarshal/PhD/simulation_codes/plotSMF_decomposed.py:61: RuntimeWarning: divide by zero encountered in log10
#   axes.plot(Max,np.log10(hist/(bin_edges[1]-bin_edges[0])/boxwidth**3),**kwargs)
# /mnt/home/mmarshal/PhD/simulation_codes/plotSMF_decomposed.py:90: RuntimeWarning: invalid value encountered in true_divide
#   FracInBin=BulgeMinBin/TotMinBin

# %% [markdown]
# Seems like we have way too many small bulges!! However, using a similar magnitude cut to the SDSS data gives us a more reasonable disk fraction at low mass - these low mass bulges are too faint to observe!
