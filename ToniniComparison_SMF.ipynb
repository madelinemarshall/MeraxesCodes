# %% [markdown]
# ## Comparison to Tonini+17 M-R Relation
# Is the reason that our M-R relations are different because the SMFs are different?
#
# Compare the original Meraxes output with Meraxes with more SF (by setting the SN ejection efficiency to be half of the default value; SbEjectionEff = 0.5), so that the SMF is larger (in closer match with Tonini+17):

# %%
#Sets plot defaults
import matplotlib
matplotlib.rcParams['font.size'] = (20)
matplotlib.rcParams['figure.figsize'] = (20,15)

import warnings
warnings.filterwarnings('ignore')

# %%
run plotSMF_tiamat125.py

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10,8)

# %%
run ToniniComparison.py

# %%
run ToniniComparison.py bulges_tiamat125_halfSNefficiency

# %% [markdown]
# See that there is improvement to the M-R relations by changing the SMF. Makes galaxies less massive

# %%
run ToniniComparison.py bulges_crotonSF_tiamat125

# %% [markdown]
# Note that the M-R relations are different using the original Croton SF prescription (galaxies spread more evenly over stellar mass), but this still doesn't match with the Tonini relations.
