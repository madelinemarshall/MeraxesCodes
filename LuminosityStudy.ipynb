# %% [markdown]
# ## Test new model with luminosity, mass, sfr relations
# First, look at mass-sfr relations

# %%
#Sets plot defaults
import matplotlib
matplotlib.rcParams['font.size'] = (20)
matplotlib.rcParams['figure.figsize'] = (20,8)

#import warnings
#warnings.filterwarnings('ignore')warnings.filterwarnings('ignore')

# %%
run MassSfrRelation.py
# Out:
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:929: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %% [markdown]
# The new model shows an additional feature in the sfr-mass relations, with an additional ~line of galaxies below the main relation.
#
# This doesn't seem to be morphology related.
#
# Seems to relate to the amount of cold gas.
#
#
# Now compare the new luminosities

# %%
run LuminosityComparison.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/home/mmarshal/PhD/simulation_codes/LuminosityComparison.py in <module>()
#      58
#      59   ##Fig: Stellar Mass vs M1600
# ---> 60   default=load_gals('default',snapshot)
#      61   gals1=load_gals(filename,snapshot)
#      62   gals2=load_gals(filename2,snapshot)
#
# /mnt/home/mmarshal/PhD/simulation_codes/LuminosityComparison.py in load_gals(filename, snapshot)
#      26   gals=meraxes.io.read_gals(data_folder+filename+meraxes_loc,\
#      27                                           snapshot=snapshot,\
# ---> 28                                           h=cosmo['h'],quiet=True)
#      29   return gals[(gals["GhostFlag"]==0)&(gals["StellarMass"]>1e-4)]
#      30
#
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/dragons/meraxes/io.py in read_gals(fname, snapshot, props, quiet, sim_props, pandas, table, h, indices)
#     177         total_read = 0
#     178         for i_core in range(n_cores):
# --> 179             galaxies = snap_group['Core%d/Galaxies' % i_core]
#     180             core_ngals = galaxies.size
#     181
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/_objects.c:2804)()
#
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     167                 raise ValueError("Invalid HDF5 object reference")
#     168         else:
# --> 169             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     170
#     171         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/_objects.c:2804)()
#
# h5py/h5o.pyx in h5py.h5o.open (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/h5o.c:3741)()
#
# h5py/h5i.pyx in h5py.h5i.wrap_identifier (/home/ilan/minonda/conda-bld/h5py_1490028290543/work/h5py/h5i.c:1237)()
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %% [markdown]
# The new model gives a very similar mass-magnitude plot.

# %%
run plotLF.py
# Out:
# Please wait a moment while I gather a list of all available modules...
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/odo/backends/pandas.py:94: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/home/mmarshal/PhD/simulation_codes/plotLF.py in <module>()
#       7 import pandas as pd
#       8 sys.path.append('Yuxiang/')
# ----> 9 import cosmolopy
#      10 from _plot_obsGLF import plot_obsGLF
#      11
#
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/cosmolopy/__init__.py in <module>()
#      86 """
#      87 from cosmolopy import *
# ---> 88 help("modules")
#      89 import cosmolopy.constants as cc
#      90 import cosmolopy.density as cden
#
# /home/mmarshal/anaconda3/lib/python3.6/_sitebuiltins.py in __call__(self, *args, **kwds)
#     101     def __call__(self, *args, **kwds):
#     102         import pydoc
# --> 103         return pydoc.help(*args, **kwds)
#
# /home/mmarshal/anaconda3/lib/python3.6/pydoc.py in __call__(self, request)
#    1856     def __call__(self, request=_GoInteractive):
#    1857         if request is not self._GoInteractive:
# -> 1858             self.help(request)
#    1859         else:
#    1860             self.intro()
#
# /home/mmarshal/anaconda3/lib/python3.6/pydoc.py in help(self, request)
#    1897             elif request == 'symbols': self.listsymbols()
#    1898             elif request == 'topics': self.listtopics()
# -> 1899             elif request == 'modules': self.listmodules()
#    1900             elif request[:8] == 'modules ':
#    1901                 self.listmodules(request.split()[1])
#
# /home/mmarshal/anaconda3/lib/python3.6/pydoc.py in listmodules(self, key)
#    2048             def onerror(modname):
#    2049                 callback(None, modname, None)
# -> 2050             ModuleScanner().run(callback, onerror=onerror)
#    2051             self.list(modules.keys())
#    2052             self.output.write('''
#
# /home/mmarshal/anaconda3/lib/python3.6/pydoc.py in run(self, callback, key, completer, onerror)
#    2077                         callback(None, modname, desc)
#    2078
# -> 2079         for importer, modname, ispkg in pkgutil.walk_packages(onerror=onerror):
#    2080             if self.quit:
#    2081                 break
#
# /home/mmarshal/anaconda3/lib/python3.6/pkgutil.py in walk_packages(path, prefix, onerror)
#      90         if info.ispkg:
#      91             try:
# ---> 92                 __import__(info.name)
#      93             except ImportError:
#      94                 if onerror is not None:
#
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/blaze/__init__.py in <module>()
#      63 from .compute.csv import *
#      64 from .compute.json import *
# ---> 65 from .compute.python import *
#      66 from .compute.pandas import *
#      67 from .compute.numpy import *
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /home/mmarshal/anaconda3/lib/python3.6/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# The M1600 functions look good!
