# %% [markdown]
# ## Test new model with luminosity, mass, sfr relations
# First, look at mass-sfr relations

# %%
run MassSfrRelation.py
# Out:
# /mnt/home/mmarshal/PhD/simulation_codes/MassSfrRelation.py:47: RuntimeWarning: divide by zero encountered in log10
#   H, xedges, yedges, img=axes.hist2d(np.log10(gals['StellarMass']*1e10), np.log10(gals['Sfr']), bins=20, range=[xlims,ylims], weights=None, cmin=1, cmax=2e4, data=None,cmap='BuPu',norm=matplotlib.colors.LogNorm(),vmax=2e4)
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6497: RuntimeWarning: invalid value encountered in greater
#   h[h > cmax] = None
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# /home/mmarshal/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:929: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# ...

# %% [markdown]
# The new model shows an additional feature in the sfr-mass relations, with an additional ~line of galaxies below the main relation.
#
# The lower relation is made up ~entirely of satellite galaxies.
# There are also more galaxies in the bulge model plot than the original model plot, which exclude galaxies with SFR=0. Does the lower sequence just not exist in the original model because the “low” SFR galaxies all just have SFR=0?
#
# It’s possible (more likely than not) that your new model is correct as it captures low sfrs in a way that the old model couldn’t.
#
# Yuxiang: The sSFR is inversely proportional to delta t. Since there is a finite snapshot time, the sSFR is therefore limited. This cuts out the bottom relation. In our new model we have additional mechanisms for producing SF, so we're no longer limited in this way. The original model did have this additional bulge - we worked out why at the time.

# %%
run LuminosityComparison.py

# %% [markdown]
# The new model gives a very similar mass-magnitude plot, and the main sequence of the SFR-magnitude plot seems alright too. We now have more galaxies at lower SFRs (expected)

# %%
#Sets plot defaults
import matplotlib
matplotlib.rcParams['figure.figsize'] = (25,8)


import warnings
warnings.filterwarnings('ignore')

# %%
run plotLF.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /mnt/home/mmarshal/PhD/simulation_codes/plotLF.py in <module>()
#      75   #    ii=0
#      76     mags_default=load_mags('default',snapshot)
# ---> 77     mags_bulges=load_mags(filename,snapshot)
#      78     #mags_2=load_mags(filename2,snapshot)
#      79
#
# /mnt/home/mmarshal/PhD/simulation_codes/plotLF.py in load_mags(filename, snapshot)
#      27 def load_mags(filename,snapshot):
#      28   if filename=='bulges_update1102_full':
# ---> 29     dust=pd.read_csv('/home/mmarshal/PhD/results/mags_output/'+filename+'/mags_6_'+format(snapshot,'03d')+'_dust.txt',sep=' ')
#      30     i775=np.array(dust)[:,0]
#      31     m1600=np.array(dust)[:,1]
#
# ...

# %% [markdown]
# The M1600 functions look good!
